# %%
# %cd classify-problem/src

# %%
# !python3 train.py \
        --model_name "vgg11" \
        --epoch 10 \
        --data ../data \
        --batchsize 16 \
        --save_weights ../weights \
        --numclass 2

# %%
# !python3 predict.py \
        --model_name "vgg11" \
        --test_path "/content/drive/MyDrive/classify-problem/predict/imgs/091611.jpg.jpg" \
        --weights ../weights/best.pt \
        --numclass 2
